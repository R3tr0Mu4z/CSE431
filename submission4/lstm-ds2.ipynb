# %%
"""
    Dataset (Bangla ( Bengali ) sentiment analysis classification benchmark dataset corpus) : https://data.mendeley.com/datasets/p6zc7krs37/4
"""
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
import pandas as pd
import string
import numpy as np
import numpy as np
import pandas as pd
from gensim.models.word2vec import Word2Vec
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.layers import *
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import *
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import PorterStemmer
from sklearn import preprocessing
from tensorflow.keras import mixed_precision
import tensorflow as tf
tf.keras.mixed_precision.experimental.Policy('mixed_float16')
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, LearningRateScheduler

# %%
# Loading Bangla ( Bengali ) sentiment analysis classification benchmark dataset
positive_sentences = []
f = open('../datasets/all_positive_8500.txt','r', encoding = 'utf-8')
for line in f:
    positive_sentences.append(line.strip())

negative_sentences = []
f = open('../datasets/all_negative_3307.txt','r', encoding = 'utf-8')
for line in f:
    negative_sentences.append(line.strip())
    
print(len(positive_sentences), 'positive sentences')
print(len(negative_sentences), 'negative sentences')

import random
random.shuffle(positive_sentences)

for i in range(len(positive_sentences)-len(negative_sentences)):
    positive_sentences.pop(0)

print(len(positive_sentences), 'positive sentences')
print(len(negative_sentences), 'negative sentences')


y_pos = [1 for i in range(len(positive_sentences))]
y_neg = [0 for i in range(len(negative_sentences))]

X = positive_sentences + negative_sentences
y = y_pos + y_neg
# Out:
# 8500 positive sentences
# 3307 negative sentences
# 3307 positive sentences
# 3307 negative sentences

# %%
w2v_model = Word2Vec.load("word2vec.model")
words = list(w2v_model.wv.index_to_key)
vocab_size = len(words)
print(vocab_size)
# Out:
# 221473

# %%
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X)
y = np.array(y)
X = tokenizer.texts_to_sequences(X)
X = pad_sequences(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)
X_train_val = X_train
y_train_val = y_train

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train_val, test_size=0.2, random_state=1, stratify=y_train_val)

# %%
from tensorflow.keras.layers import Embedding
def gensim_to_keras_embedding(model, train_embeddings=False):
    """Get a Keras 'Embedding' layer with weights set from Word2Vec model's learned word embeddings.

    Parameters
    ----------
    train_embeddings : bool
        If False, the returned weights are frozen and stopped from being updated.
        If True, the weights can / will be further updated in Keras.

    Returns
    -------
    `keras.layers.Embedding`
        Embedding layer, to be used as input to deeper network layers.

    """
    keyed_vectors = model.wv  # structure holding the result of training
    weights = keyed_vectors.vectors  # vectors themselves, a 2D numpy array    
    index_to_key = keyed_vectors.index_to_key  # which row in `weights` corresponds to which word?

    layer = Embedding(
        input_dim=weights.shape[0],
        output_dim=weights.shape[1],
        weights=[weights],
        trainable=train_embeddings,
    )
    return layer

# %%
def nlp_lstm(w2v):
    inputs = Input(shape=(X_train[0].shape[-1],))

    embedding_layer = gensim_to_keras_embedding(w2v)
    
    embedding_layer = embedding_layer(inputs)

    lstm1 = Bidirectional(LSTM(100,return_sequences=True, return_state=True))(embedding_layer)
    lstm2 = Bidirectional(LSTM(100,return_sequences=True, return_state=True))(lstm1)
    output = Dense(units=1, activation='sigmoid')(lstm2[1])
    
    model = Model(inputs, output)
    return model


model = nlp_lstm(w2v_model)



checkpoint = ModelCheckpoint('./weight_cp/weight_lstm.hdf5', save_freq="epoch",  verbose=1, monitor='val_accuracy', save_best_only=True,
    save_weights_only=False)

metrics = ['accuracy']
optimizer = Adam(0.00005)
model.compile(optimizer = optimizer, loss='binary_crossentropy', metrics=metrics)
model.summary()
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[checkpoint])
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 255)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 255, 100)     22147300    input_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) [(None, 255, 200), ( 160800      embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) [(None, 255, 200), ( 240800      bidirectional_4[0][0]
#                                                                  bidirectional_4[0][1]
#                                                                  bidirectional_4[0][2]
#                                                                  bidirectional_4[0][3]
#                                                                  bidirectional_4[0][4]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            101         bidirectional_5[0][1]
# ==================================================================================================
# Total params: 22,549,001
# Trainable params: 401,701
# Non-trainable params: 22,147,300
# __________________________________________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_5/backward_lstm_5/lstm_cell_47/kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/recurrent_kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_5/backward_lstm_5/lstm_cell_47/kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/recurrent_kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_5/backward_lstm_5/lstm_cell_47/kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/recurrent_kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_5/backward_lstm_5/lstm_cell_47/kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/recurrent_kernel:0', 'bidirectional_5/backward_lstm_5/lstm_cell_47/bias:0'] when minimizing the loss.
# 132/133 [============================>.] - ETA: 0s - loss: 0.6629 - accuracy: 0.6262
# Epoch 00001: val_accuracy improved from -inf to 0.74976, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 7s 49ms/step - loss: 0.6626 - accuracy: 0.6267 - val_loss: 0.6065 - val_accuracy: 0.7498
# Epoch 2/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.5229 - accuracy: 0.7583
# Epoch 00002: val_accuracy improved from 0.74976 to 0.78093, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.5227 - accuracy: 0.7585 - val_loss: 0.4614 - val_accuracy: 0.7809
# Epoch 3/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.4205 - accuracy: 0.8042
# Epoch 00003: val_accuracy improved from 0.78093 to 0.80831, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.4202 - accuracy: 0.8043 - val_loss: 0.4011 - val_accuracy: 0.8083
# Epoch 4/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8282
# Epoch 00004: val_accuracy improved from 0.80831 to 0.83097, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.3737 - accuracy: 0.8282 - val_loss: 0.3740 - val_accuracy: 0.8310
# Epoch 5/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8495
# Epoch 00005: val_accuracy improved from 0.83097 to 0.84703, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 6s 42ms/step - loss: 0.3375 - accuracy: 0.8495 - val_loss: 0.3520 - val_accuracy: 0.8470
# Epoch 6/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8667
# Epoch 00006: val_accuracy did not improve from 0.84703
# 133/133 [==============================] - 5s 37ms/step - loss: 0.3091 - accuracy: 0.8667 - val_loss: 0.3486 - val_accuracy: 0.8310
# Epoch 7/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8767
# Epoch 00007: val_accuracy improved from 0.84703 to 0.85552, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.2854 - accuracy: 0.8767 - val_loss: 0.3295 - val_accuracy: 0.8555
# Epoch 8/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.8854
# Epoch 00008: val_accuracy did not improve from 0.85552
# 133/133 [==============================] - 5s 38ms/step - loss: 0.2640 - accuracy: 0.8854 - val_loss: 0.3355 - val_accuracy: 0.8404
# Epoch 9/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.8970
# Epoch 00009: val_accuracy did not improve from 0.85552
# 133/133 [==============================] - 5s 38ms/step - loss: 0.2452 - accuracy: 0.8970 - val_loss: 0.3458 - val_accuracy: 0.8461
# Epoch 10/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9069
# Epoch 00010: val_accuracy improved from 0.85552 to 0.86497, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.2287 - accuracy: 0.9069 - val_loss: 0.3119 - val_accuracy: 0.8650
# Epoch 11/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9194
# Epoch 00011: val_accuracy did not improve from 0.86497
# 133/133 [==============================] - 5s 37ms/step - loss: 0.2106 - accuracy: 0.9194 - val_loss: 0.3276 - val_accuracy: 0.8536
# Epoch 12/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9223
# Epoch 00012: val_accuracy improved from 0.86497 to 0.87535, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.2005 - accuracy: 0.9223 - val_loss: 0.3012 - val_accuracy: 0.8754
# Epoch 13/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9301
# Epoch 00013: val_accuracy did not improve from 0.87535
# 133/133 [==============================] - 5s 38ms/step - loss: 0.1856 - accuracy: 0.9301 - val_loss: 0.3096 - val_accuracy: 0.8640
# Epoch 14/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9400
# Epoch 00014: val_accuracy did not improve from 0.87535
# 133/133 [==============================] - 5s 37ms/step - loss: 0.1705 - accuracy: 0.9400 - val_loss: 0.3058 - val_accuracy: 0.8716
# Epoch 15/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9435
# Epoch 00015: val_accuracy improved from 0.87535 to 0.88669, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.1610 - accuracy: 0.9435 - val_loss: 0.3036 - val_accuracy: 0.8867
# Epoch 16/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9513
# Epoch 00016: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.1454 - accuracy: 0.9513 - val_loss: 0.3076 - val_accuracy: 0.8763
# Epoch 17/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9565
# Epoch 00017: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.1319 - accuracy: 0.9565 - val_loss: 0.3314 - val_accuracy: 0.8744
# Epoch 18/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9577
# Epoch 00018: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.1257 - accuracy: 0.9577 - val_loss: 0.3106 - val_accuracy: 0.8820
# Epoch 19/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9589
# Epoch 00019: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.1172 - accuracy: 0.9589 - val_loss: 0.3204 - val_accuracy: 0.8801
# Epoch 20/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9660
# Epoch 00020: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.1089 - accuracy: 0.9660 - val_loss: 0.3317 - val_accuracy: 0.8839
# Epoch 21/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9695
# Epoch 00021: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0986 - accuracy: 0.9695 - val_loss: 0.3314 - val_accuracy: 0.8848
# Epoch 22/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9716
# Epoch 00022: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0916 - accuracy: 0.9716 - val_loss: 0.3411 - val_accuracy: 0.8810
# Epoch 23/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9733
# Epoch 00023: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0876 - accuracy: 0.9733 - val_loss: 0.3653 - val_accuracy: 0.8801
# Epoch 24/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9759
# Epoch 00024: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0812 - accuracy: 0.9759 - val_loss: 0.3487 - val_accuracy: 0.8763
# Epoch 25/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9797
# Epoch 00025: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0713 - accuracy: 0.9797 - val_loss: 0.3580 - val_accuracy: 0.8848
# Epoch 26/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9792
# Epoch 00026: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0663 - accuracy: 0.9792 - val_loss: 0.3627 - val_accuracy: 0.8801
# Epoch 27/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9825
# Epoch 00027: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0611 - accuracy: 0.9825 - val_loss: 0.3766 - val_accuracy: 0.8857
# Epoch 28/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9818
# Epoch 00028: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0618 - accuracy: 0.9818 - val_loss: 0.3880 - val_accuracy: 0.8829
# Epoch 29/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9861
# Epoch 00029: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0522 - accuracy: 0.9861 - val_loss: 0.3653 - val_accuracy: 0.8829
# Epoch 30/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9863
# Epoch 00030: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0495 - accuracy: 0.9863 - val_loss: 0.4161 - val_accuracy: 0.8725
# Epoch 31/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9879
# Epoch 00031: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0428 - accuracy: 0.9879 - val_loss: 0.4232 - val_accuracy: 0.8848
# Epoch 32/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9858
# Epoch 00032: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0478 - accuracy: 0.9858 - val_loss: 0.4038 - val_accuracy: 0.8848
# Epoch 33/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9910
# Epoch 00033: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0366 - accuracy: 0.9910 - val_loss: 0.4254 - val_accuracy: 0.8829
# Epoch 34/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9934
# Epoch 00034: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 35ms/step - loss: 0.0321 - accuracy: 0.9934 - val_loss: 0.4586 - val_accuracy: 0.8839
# Epoch 35/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9934
# Epoch 00035: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0298 - accuracy: 0.9934 - val_loss: 0.4516 - val_accuracy: 0.8839
# Epoch 36/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9891
# Epoch 00036: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0368 - accuracy: 0.9891 - val_loss: 0.4353 - val_accuracy: 0.8820
# Epoch 37/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9934
# Epoch 00037: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0287 - accuracy: 0.9934 - val_loss: 0.4625 - val_accuracy: 0.8857
# Epoch 38/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9946
# Epoch 00038: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0244 - accuracy: 0.9946 - val_loss: 0.4816 - val_accuracy: 0.8801
# Epoch 39/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9967
# Epoch 00039: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0185 - accuracy: 0.9967 - val_loss: 0.5140 - val_accuracy: 0.8772
# Epoch 40/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9948
# Epoch 00040: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0220 - accuracy: 0.9948 - val_loss: 0.5032 - val_accuracy: 0.8763
# Epoch 41/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9974
# Epoch 00041: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 40ms/step - loss: 0.0180 - accuracy: 0.9974 - val_loss: 0.5059 - val_accuracy: 0.8829
# Epoch 42/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9972
# Epoch 00042: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0175 - accuracy: 0.9972 - val_loss: 0.5450 - val_accuracy: 0.8763
# Epoch 43/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9965
# Epoch 00043: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0186 - accuracy: 0.9965 - val_loss: 0.5073 - val_accuracy: 0.8848
# Epoch 44/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9913
# Epoch 00044: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0322 - accuracy: 0.9913 - val_loss: 0.5019 - val_accuracy: 0.8820
# Epoch 45/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9967
# Epoch 00045: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0181 - accuracy: 0.9967 - val_loss: 0.5273 - val_accuracy: 0.8857
# Epoch 46/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9967
# Epoch 00046: val_accuracy did not improve from 0.88669
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0160 - accuracy: 0.9967 - val_loss: 0.5125 - val_accuracy: 0.8848
# Epoch 47/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9976
# Epoch 00047: val_accuracy improved from 0.88669 to 0.88763, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 0.5140 - val_accuracy: 0.8876
# Epoch 48/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9967
# Epoch 00048: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 0.5521 - val_accuracy: 0.8791
# Epoch 49/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9766
# Epoch 00049: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0642 - accuracy: 0.9766 - val_loss: 0.4570 - val_accuracy: 0.8801
# Epoch 50/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9953
# Epoch 00050: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0199 - accuracy: 0.9953 - val_loss: 0.4755 - val_accuracy: 0.8820
# Epoch 51/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9948
# Epoch 00051: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0217 - accuracy: 0.9948 - val_loss: 0.4829 - val_accuracy: 0.8867
# Epoch 52/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9979
# Epoch 00052: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.5136 - val_accuracy: 0.8829
# Epoch 53/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9969
# Epoch 00053: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.5219 - val_accuracy: 0.8867
# Epoch 54/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9986
# Epoch 00054: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0111 - accuracy: 0.9986 - val_loss: 0.5485 - val_accuracy: 0.8848
# Epoch 55/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9983
# Epoch 00055: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 39ms/step - loss: 0.0093 - accuracy: 0.9983 - val_loss: 0.5468 - val_accuracy: 0.8857
# Epoch 56/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9986
# Epoch 00056: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0089 - accuracy: 0.9986 - val_loss: 0.5524 - val_accuracy: 0.8839
# Epoch 57/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9979
# Epoch 00057: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0110 - accuracy: 0.9979 - val_loss: 0.5610 - val_accuracy: 0.8829
# Epoch 58/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9991
# Epoch 00058: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 0.5828 - val_accuracy: 0.8810
# Epoch 59/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9979
# Epoch 00059: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 35ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.5662 - val_accuracy: 0.8839
# Epoch 60/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9991
# Epoch 00060: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 35ms/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 0.6124 - val_accuracy: 0.8763
# Epoch 61/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9991
# Epoch 00061: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.5825 - val_accuracy: 0.8867
# Epoch 62/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9927
# Epoch 00062: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 0.5368 - val_accuracy: 0.8839
# Epoch 63/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9986
# Epoch 00063: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 38ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.5895 - val_accuracy: 0.8867
# Epoch 64/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9991
# Epoch 00064: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0058 - accuracy: 0.9991 - val_loss: 0.5925 - val_accuracy: 0.8810
# Epoch 65/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9967
# Epoch 00065: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 35ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.6235 - val_accuracy: 0.8735
# Epoch 66/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9972
# Epoch 00066: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 35ms/step - loss: 0.0124 - accuracy: 0.9972 - val_loss: 0.5762 - val_accuracy: 0.8857
# Epoch 67/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9998
# Epoch 00067: val_accuracy did not improve from 0.88763
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0044 - accuracy: 0.9998 - val_loss: 0.6219 - val_accuracy: 0.8782
# Epoch 68/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9995
# Epoch 00068: val_accuracy improved from 0.88763 to 0.88857, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.6088 - val_accuracy: 0.8886
# Epoch 69/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9993
# Epoch 00069: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.6411 - val_accuracy: 0.8829
# Epoch 70/100
# 132/133 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998
# Epoch 00070: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 41ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.6353 - val_accuracy: 0.8791
# Epoch 71/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998
# Epoch 00071: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.6525 - val_accuracy: 0.8829
# Epoch 72/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 00072: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.6344 - val_accuracy: 0.8801
# Epoch 73/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995
# Epoch 00073: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.6519 - val_accuracy: 0.8810
# Epoch 74/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995
# Epoch 00074: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.6563 - val_accuracy: 0.8810
# Epoch 75/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9913
# Epoch 00075: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0237 - accuracy: 0.9913 - val_loss: 0.5997 - val_accuracy: 0.8810
# Epoch 76/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9981
# Epoch 00076: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.6269 - val_accuracy: 0.8820
# Epoch 77/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9934
# Epoch 00077: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.5724 - val_accuracy: 0.8857
# Epoch 78/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9995
# Epoch 00078: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.5865 - val_accuracy: 0.8886
# Epoch 79/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9995
# Epoch 00079: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.6271 - val_accuracy: 0.8820
# Epoch 80/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9993
# Epoch 00080: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.6429 - val_accuracy: 0.8820
# Epoch 81/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6732 - val_accuracy: 0.8810
# Epoch 82/100
# 133/133 [==============================] - ETA: 0s - loss: 7.1240e-04 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 7.1240e-04 - accuracy: 1.0000 - val_loss: 0.6883 - val_accuracy: 0.8791
# Epoch 83/100
# 133/133 [==============================] - ETA: 0s - loss: 5.6966e-04 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 5.6966e-04 - accuracy: 1.0000 - val_loss: 0.7051 - val_accuracy: 0.8791
# Epoch 84/100
# 133/133 [==============================] - ETA: 0s - loss: 5.0331e-04 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 5.0331e-04 - accuracy: 1.0000 - val_loss: 0.7187 - val_accuracy: 0.8801
# Epoch 85/100
# 133/133 [==============================] - ETA: 0s - loss: 4.5115e-04 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 4.5115e-04 - accuracy: 1.0000 - val_loss: 0.7280 - val_accuracy: 0.8801
# Epoch 86/100
# 133/133 [==============================] - ETA: 0s - loss: 4.0690e-04 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 4.0690e-04 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.8801
# Epoch 87/100
# 133/133 [==============================] - ETA: 0s - loss: 3.6446e-04 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 3.6446e-04 - accuracy: 1.0000 - val_loss: 0.7545 - val_accuracy: 0.8810
# Epoch 88/100
# 132/133 [============================>.] - ETA: 0s - loss: 3.2904e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 3.2872e-04 - accuracy: 1.0000 - val_loss: 0.7604 - val_accuracy: 0.8801
# Epoch 89/100
# 133/133 [==============================] - ETA: 0s - loss: 3.0893e-04 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 3.0893e-04 - accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 0.8791
# Epoch 90/100
# 133/133 [==============================] - ETA: 0s - loss: 2.9270e-04 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 2.9270e-04 - accuracy: 1.0000 - val_loss: 0.7731 - val_accuracy: 0.8791
# Epoch 91/100
# 133/133 [==============================] - ETA: 0s - loss: 2.6026e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 2.6026e-04 - accuracy: 1.0000 - val_loss: 0.7830 - val_accuracy: 0.8801
# Epoch 92/100
# 133/133 [==============================] - ETA: 0s - loss: 2.3733e-04 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 38ms/step - loss: 2.3733e-04 - accuracy: 1.0000 - val_loss: 0.7974 - val_accuracy: 0.8791
# Epoch 93/100
# 133/133 [==============================] - ETA: 0s - loss: 2.2587e-04 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 38ms/step - loss: 2.2587e-04 - accuracy: 1.0000 - val_loss: 0.8111 - val_accuracy: 0.8791
# Epoch 94/100
# 133/133 [==============================] - ETA: 0s - loss: 2.0985e-04 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 2.0985e-04 - accuracy: 1.0000 - val_loss: 0.8038 - val_accuracy: 0.8801
# Epoch 95/100
# 133/133 [==============================] - ETA: 0s - loss: 1.9055e-04 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 1.9055e-04 - accuracy: 1.0000 - val_loss: 0.8084 - val_accuracy: 0.8820
# Epoch 96/100
# 133/133 [==============================] - ETA: 0s - loss: 1.8041e-04 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 1.8041e-04 - accuracy: 1.0000 - val_loss: 0.8164 - val_accuracy: 0.8820
# Epoch 97/100
# 133/133 [==============================] - ETA: 0s - loss: 1.6530e-04 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 1.6530e-04 - accuracy: 1.0000 - val_loss: 0.8302 - val_accuracy: 0.8810
# Epoch 98/100
# 133/133 [==============================] - ETA: 0s - loss: 1.5541e-04 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 1.5541e-04 - accuracy: 1.0000 - val_loss: 0.8311 - val_accuracy: 0.8820
# Epoch 99/100
# 133/133 [==============================] - ETA: 0s - loss: 1.4755e-04 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 37ms/step - loss: 1.4755e-04 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.8839
# Epoch 100/100
# 133/133 [==============================] - ETA: 0s - loss: 1.3857e-04 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 39ms/step - loss: 1.3857e-04 - accuracy: 1.0000 - val_loss: 0.8382 - val_accuracy: 0.8829

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
model = load_model('./weight_cp/weight_lstm.hdf5')
predictions = model.predict(X_test)
predictions = np.where(predictions > 0.5, 1, 0)
y_pred = []
for p in predictions:
    y_pred.append(p[0])
y_pred = np.array(y_pred)
from sklearn.metrics import classification_report, accuracy_score
print("CLASSIFICATION REPORT OF LSTM")
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# CLASSIFICATION REPORT OF LSTM
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89       661
#            1       0.88      0.90      0.89       662
#
#     accuracy                           0.89      1323
#    macro avg       0.89      0.89      0.89      1323
# weighted avg       0.89      0.89      0.89      1323
#
# 0.8873771730914588

# %%
def nlp_ds(w2v):
    inputs = Input(shape=(X_train[0].shape[-1],))

    embedding_layer = gensim_to_keras_embedding(w2v)
    
    embedding_layer = embedding_layer(inputs)

    lstm1 = Bidirectional(LSTM(100,return_sequences=True, return_state=True))(embedding_layer)
    lstm2 = Bidirectional(LSTM(100,return_sequences=True, return_state=True))(lstm1)
    
    output1 = Dense(units=1, activation='sigmoid', name='lstm_1')(lstm1[1])
    output2 = Dense(units=1, activation='sigmoid', name='lstm_2')(lstm2[1])
    model = Model(inputs, [output1, output2])
    return model


model = nlp_ds(w2v_model)



checkpoint = ModelCheckpoint('./weight_cp/weight_lstm.hdf5', save_freq="epoch",  verbose=1, monitor='val_lstm_2_accuracy', save_best_only=True,
    save_weights_only=False)

metrics = ['accuracy']
optimizer = Adam(0.00005)
model.compile(optimizer = optimizer, loss='binary_crossentropy', metrics=metrics)
model.summary()
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[checkpoint])
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 255)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 255, 100)     22147300    input_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) [(None, 255, 200), ( 160800      embedding_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) [(None, 255, 200), ( 240800      bidirectional_6[0][0]
#                                                                  bidirectional_6[0][1]
#                                                                  bidirectional_6[0][2]
#                                                                  bidirectional_6[0][3]
#                                                                  bidirectional_6[0][4]
# __________________________________________________________________________________________________
# lstm_1 (Dense)                  (None, 1)            101         bidirectional_6[0][1]
# __________________________________________________________________________________________________
# lstm_2 (Dense)                  (None, 1)            101         bidirectional_7[0][1]
# ==================================================================================================
# Total params: 22,549,102
# Trainable params: 401,802
# Non-trainable params: 22,147,300
# __________________________________________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_7/backward_lstm_7/lstm_cell_59/kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/recurrent_kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_7/backward_lstm_7/lstm_cell_59/kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/recurrent_kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_7/backward_lstm_7/lstm_cell_59/kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/recurrent_kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bidirectional_7/backward_lstm_7/lstm_cell_59/kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/recurrent_kernel:0', 'bidirectional_7/backward_lstm_7/lstm_cell_59/bias:0'] when minimizing the loss.
# 133/133 [==============================] - ETA: 0s - loss: 1.3235 - lstm_1_loss: 0.6643 - lstm_2_loss: 0.6592 - lstm_1_accuracy: 0.6148 - lstm_2_accuracy: 0.6418
# Epoch 00001: val_lstm_2_accuracy improved from -inf to 0.72332, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 6s 48ms/step - loss: 1.3235 - lstm_1_loss: 0.6643 - lstm_2_loss: 0.6592 - lstm_1_accuracy: 0.6148 - lstm_2_accuracy: 0.6418 - val_loss: 1.2546 - val_lstm_1_loss: 0.6378 - val_lstm_2_loss: 0.6167 - val_lstm_1_accuracy: 0.6516 - val_lstm_2_accuracy: 0.7233
# Epoch 2/100
# 133/133 [==============================] - ETA: 0s - loss: 1.1399 - lstm_1_loss: 0.6058 - lstm_2_loss: 0.5340 - lstm_1_accuracy: 0.7011 - lstm_2_accuracy: 0.7514
# Epoch 00002: val_lstm_2_accuracy improved from 0.72332 to 0.77148, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 1.1399 - lstm_1_loss: 0.6058 - lstm_2_loss: 0.5340 - lstm_1_accuracy: 0.7011 - lstm_2_accuracy: 0.7514 - val_loss: 1.0854 - val_lstm_1_loss: 0.5917 - val_lstm_2_loss: 0.4937 - val_lstm_1_accuracy: 0.7148 - val_lstm_2_accuracy: 0.7715
# Epoch 3/100
# 133/133 [==============================] - ETA: 0s - loss: 0.9884 - lstm_1_loss: 0.5634 - lstm_2_loss: 0.4249 - lstm_1_accuracy: 0.7439 - lstm_2_accuracy: 0.8095
# Epoch 00003: val_lstm_2_accuracy improved from 0.77148 to 0.82625, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.9884 - lstm_1_loss: 0.5634 - lstm_2_loss: 0.4249 - lstm_1_accuracy: 0.7439 - lstm_2_accuracy: 0.8095 - val_loss: 0.9477 - val_lstm_1_loss: 0.5551 - val_lstm_2_loss: 0.3926 - val_lstm_1_accuracy: 0.7460 - val_lstm_2_accuracy: 0.8263
# Epoch 4/100
# 133/133 [==============================] - ETA: 0s - loss: 0.8987 - lstm_1_loss: 0.5284 - lstm_2_loss: 0.3703 - lstm_1_accuracy: 0.7776 - lstm_2_accuracy: 0.8367
# Epoch 00004: val_lstm_2_accuracy improved from 0.82625 to 0.83664, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.8987 - lstm_1_loss: 0.5284 - lstm_2_loss: 0.3703 - lstm_1_accuracy: 0.7776 - lstm_2_accuracy: 0.8367 - val_loss: 0.8882 - val_lstm_1_loss: 0.5246 - val_lstm_2_loss: 0.3636 - val_lstm_1_accuracy: 0.7705 - val_lstm_2_accuracy: 0.8366
# Epoch 5/100
# 133/133 [==============================] - ETA: 0s - loss: 0.8352 - lstm_1_loss: 0.4978 - lstm_2_loss: 0.3374 - lstm_1_accuracy: 0.7944 - lstm_2_accuracy: 0.8478
# Epoch 00005: val_lstm_2_accuracy improved from 0.83664 to 0.84042, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.8352 - lstm_1_loss: 0.4978 - lstm_2_loss: 0.3374 - lstm_1_accuracy: 0.7944 - lstm_2_accuracy: 0.8478 - val_loss: 0.8453 - val_lstm_1_loss: 0.4976 - val_lstm_2_loss: 0.3477 - val_lstm_1_accuracy: 0.7800 - val_lstm_2_accuracy: 0.8404
# Epoch 6/100
# 133/133 [==============================] - ETA: 0s - loss: 0.7858 - lstm_1_loss: 0.4698 - lstm_2_loss: 0.3160 - lstm_1_accuracy: 0.8048 - lstm_2_accuracy: 0.8589
# Epoch 00006: val_lstm_2_accuracy did not improve from 0.84042
# 133/133 [==============================] - 5s 37ms/step - loss: 0.7858 - lstm_1_loss: 0.4698 - lstm_2_loss: 0.3160 - lstm_1_accuracy: 0.8048 - lstm_2_accuracy: 0.8589 - val_loss: 0.8401 - val_lstm_1_loss: 0.4735 - val_lstm_2_loss: 0.3666 - val_lstm_1_accuracy: 0.7923 - val_lstm_2_accuracy: 0.8291
# Epoch 7/100
# 133/133 [==============================] - ETA: 0s - loss: 0.7412 - lstm_1_loss: 0.4432 - lstm_2_loss: 0.2980 - lstm_1_accuracy: 0.8211 - lstm_2_accuracy: 0.8733
# Epoch 00007: val_lstm_2_accuracy improved from 0.84042 to 0.85836, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.7412 - lstm_1_loss: 0.4432 - lstm_2_loss: 0.2980 - lstm_1_accuracy: 0.8211 - lstm_2_accuracy: 0.8733 - val_loss: 0.7828 - val_lstm_1_loss: 0.4502 - val_lstm_2_loss: 0.3326 - val_lstm_1_accuracy: 0.8055 - val_lstm_2_accuracy: 0.8584
# Epoch 8/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6979 - lstm_1_loss: 0.4183 - lstm_2_loss: 0.2796 - lstm_1_accuracy: 0.8318 - lstm_2_accuracy: 0.8778
# Epoch 00008: val_lstm_2_accuracy did not improve from 0.85836
# 133/133 [==============================] - 5s 37ms/step - loss: 0.6979 - lstm_1_loss: 0.4183 - lstm_2_loss: 0.2796 - lstm_1_accuracy: 0.8318 - lstm_2_accuracy: 0.8778 - val_loss: 0.7517 - val_lstm_1_loss: 0.4279 - val_lstm_2_loss: 0.3238 - val_lstm_1_accuracy: 0.8111 - val_lstm_2_accuracy: 0.8584
# Epoch 9/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6583 - lstm_1_loss: 0.3942 - lstm_2_loss: 0.2640 - lstm_1_accuracy: 0.8419 - lstm_2_accuracy: 0.8854
# Epoch 00009: val_lstm_2_accuracy improved from 0.85836 to 0.86497, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.6583 - lstm_1_loss: 0.3942 - lstm_2_loss: 0.2640 - lstm_1_accuracy: 0.8419 - lstm_2_accuracy: 0.8854 - val_loss: 0.7200 - val_lstm_1_loss: 0.4092 - val_lstm_2_loss: 0.3109 - val_lstm_1_accuracy: 0.8281 - val_lstm_2_accuracy: 0.8650
# Epoch 10/100
# 133/133 [==============================] - ETA: 0s - loss: 0.6254 - lstm_1_loss: 0.3742 - lstm_2_loss: 0.2512 - lstm_1_accuracy: 0.8455 - lstm_2_accuracy: 0.8979
# Epoch 00010: val_lstm_2_accuracy did not improve from 0.86497
# 133/133 [==============================] - 5s 37ms/step - loss: 0.6254 - lstm_1_loss: 0.3742 - lstm_2_loss: 0.2512 - lstm_1_accuracy: 0.8455 - lstm_2_accuracy: 0.8979 - val_loss: 0.7270 - val_lstm_1_loss: 0.3968 - val_lstm_2_loss: 0.3302 - val_lstm_1_accuracy: 0.8329 - val_lstm_2_accuracy: 0.8508
# Epoch 11/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5985 - lstm_1_loss: 0.3554 - lstm_2_loss: 0.2431 - lstm_1_accuracy: 0.8566 - lstm_2_accuracy: 0.8991
# Epoch 00011: val_lstm_2_accuracy improved from 0.86497 to 0.86780, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.5985 - lstm_1_loss: 0.3554 - lstm_2_loss: 0.2431 - lstm_1_accuracy: 0.8566 - lstm_2_accuracy: 0.8991 - val_loss: 0.6867 - val_lstm_1_loss: 0.3779 - val_lstm_2_loss: 0.3089 - val_lstm_1_accuracy: 0.8404 - val_lstm_2_accuracy: 0.8678
# Epoch 12/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5587 - lstm_1_loss: 0.3353 - lstm_2_loss: 0.2234 - lstm_1_accuracy: 0.8641 - lstm_2_accuracy: 0.9114
# Epoch 00012: val_lstm_2_accuracy improved from 0.86780 to 0.86969, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.5587 - lstm_1_loss: 0.3353 - lstm_2_loss: 0.2234 - lstm_1_accuracy: 0.8641 - lstm_2_accuracy: 0.9114 - val_loss: 0.6659 - val_lstm_1_loss: 0.3636 - val_lstm_2_loss: 0.3022 - val_lstm_1_accuracy: 0.8470 - val_lstm_2_accuracy: 0.8697
# Epoch 13/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5347 - lstm_1_loss: 0.3211 - lstm_2_loss: 0.2136 - lstm_1_accuracy: 0.8684 - lstm_2_accuracy: 0.9140
# Epoch 00013: val_lstm_2_accuracy did not improve from 0.86969
# 133/133 [==============================] - 5s 37ms/step - loss: 0.5347 - lstm_1_loss: 0.3211 - lstm_2_loss: 0.2136 - lstm_1_accuracy: 0.8684 - lstm_2_accuracy: 0.9140 - val_loss: 0.6575 - val_lstm_1_loss: 0.3535 - val_lstm_2_loss: 0.3041 - val_lstm_1_accuracy: 0.8489 - val_lstm_2_accuracy: 0.8697
# Epoch 14/100
# 133/133 [==============================] - ETA: 0s - loss: 0.5038 - lstm_1_loss: 0.3057 - lstm_2_loss: 0.1981 - lstm_1_accuracy: 0.8752 - lstm_2_accuracy: 0.9216
# Epoch 00014: val_lstm_2_accuracy improved from 0.86969 to 0.87724, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 40ms/step - loss: 0.5038 - lstm_1_loss: 0.3057 - lstm_2_loss: 0.1981 - lstm_1_accuracy: 0.8752 - lstm_2_accuracy: 0.9216 - val_loss: 0.6286 - val_lstm_1_loss: 0.3422 - val_lstm_2_loss: 0.2864 - val_lstm_1_accuracy: 0.8480 - val_lstm_2_accuracy: 0.8772
# Epoch 15/100
# 133/133 [==============================] - ETA: 0s - loss: 0.4792 - lstm_1_loss: 0.2927 - lstm_2_loss: 0.1864 - lstm_1_accuracy: 0.8819 - lstm_2_accuracy: 0.9308
# Epoch 00015: val_lstm_2_accuracy did not improve from 0.87724
# 133/133 [==============================] - 5s 37ms/step - loss: 0.4792 - lstm_1_loss: 0.2927 - lstm_2_loss: 0.1864 - lstm_1_accuracy: 0.8819 - lstm_2_accuracy: 0.9308 - val_loss: 0.6311 - val_lstm_1_loss: 0.3345 - val_lstm_2_loss: 0.2967 - val_lstm_1_accuracy: 0.8593 - val_lstm_2_accuracy: 0.8735
# Epoch 16/100
# 133/133 [==============================] - ETA: 0s - loss: 0.4628 - lstm_1_loss: 0.2853 - lstm_2_loss: 0.1775 - lstm_1_accuracy: 0.8852 - lstm_2_accuracy: 0.9338
# Epoch 00016: val_lstm_2_accuracy improved from 0.87724 to 0.88196, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.4628 - lstm_1_loss: 0.2853 - lstm_2_loss: 0.1775 - lstm_1_accuracy: 0.8852 - lstm_2_accuracy: 0.9338 - val_loss: 0.6127 - val_lstm_1_loss: 0.3284 - val_lstm_2_loss: 0.2843 - val_lstm_1_accuracy: 0.8536 - val_lstm_2_accuracy: 0.8820
# Epoch 17/100
# 133/133 [==============================] - ETA: 0s - loss: 0.4380 - lstm_1_loss: 0.2722 - lstm_2_loss: 0.1658 - lstm_1_accuracy: 0.8953 - lstm_2_accuracy: 0.9383
# Epoch 00017: val_lstm_2_accuracy did not improve from 0.88196
# 133/133 [==============================] - 5s 37ms/step - loss: 0.4380 - lstm_1_loss: 0.2722 - lstm_2_loss: 0.1658 - lstm_1_accuracy: 0.8953 - lstm_2_accuracy: 0.9383 - val_loss: 0.6835 - val_lstm_1_loss: 0.3768 - val_lstm_2_loss: 0.3067 - val_lstm_1_accuracy: 0.8045 - val_lstm_2_accuracy: 0.8687
# Epoch 18/100
# 133/133 [==============================] - ETA: 0s - loss: 0.4206 - lstm_1_loss: 0.2661 - lstm_2_loss: 0.1545 - lstm_1_accuracy: 0.8941 - lstm_2_accuracy: 0.9421
# Epoch 00018: val_lstm_2_accuracy did not improve from 0.88196
# 133/133 [==============================] - 5s 37ms/step - loss: 0.4206 - lstm_1_loss: 0.2661 - lstm_2_loss: 0.1545 - lstm_1_accuracy: 0.8941 - lstm_2_accuracy: 0.9421 - val_loss: 0.6047 - val_lstm_1_loss: 0.3186 - val_lstm_2_loss: 0.2861 - val_lstm_1_accuracy: 0.8631 - val_lstm_2_accuracy: 0.8810
# Epoch 19/100
# 133/133 [==============================] - ETA: 0s - loss: 0.4001 - lstm_1_loss: 0.2544 - lstm_2_loss: 0.1457 - lstm_1_accuracy: 0.9010 - lstm_2_accuracy: 0.9492
# Epoch 00019: val_lstm_2_accuracy improved from 0.88196 to 0.88480, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 41ms/step - loss: 0.4001 - lstm_1_loss: 0.2544 - lstm_2_loss: 0.1457 - lstm_1_accuracy: 0.9010 - lstm_2_accuracy: 0.9492 - val_loss: 0.6067 - val_lstm_1_loss: 0.3163 - val_lstm_2_loss: 0.2905 - val_lstm_1_accuracy: 0.8650 - val_lstm_2_accuracy: 0.8848
# Epoch 20/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3821 - lstm_1_loss: 0.2484 - lstm_2_loss: 0.1336 - lstm_1_accuracy: 0.9052 - lstm_2_accuracy: 0.9553
# Epoch 00020: val_lstm_2_accuracy did not improve from 0.88480
# 133/133 [==============================] - 5s 36ms/step - loss: 0.3821 - lstm_1_loss: 0.2484 - lstm_2_loss: 0.1336 - lstm_1_accuracy: 0.9052 - lstm_2_accuracy: 0.9553 - val_loss: 0.6168 - val_lstm_1_loss: 0.3167 - val_lstm_2_loss: 0.3001 - val_lstm_1_accuracy: 0.8621 - val_lstm_2_accuracy: 0.8829
# Epoch 21/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3634 - lstm_1_loss: 0.2399 - lstm_2_loss: 0.1235 - lstm_1_accuracy: 0.9076 - lstm_2_accuracy: 0.9594
# Epoch 00021: val_lstm_2_accuracy did not improve from 0.88480
# 133/133 [==============================] - 5s 36ms/step - loss: 0.3634 - lstm_1_loss: 0.2399 - lstm_2_loss: 0.1235 - lstm_1_accuracy: 0.9076 - lstm_2_accuracy: 0.9594 - val_loss: 0.6399 - val_lstm_1_loss: 0.3233 - val_lstm_2_loss: 0.3166 - val_lstm_1_accuracy: 0.8527 - val_lstm_2_accuracy: 0.8697
# Epoch 22/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3457 - lstm_1_loss: 0.2325 - lstm_2_loss: 0.1133 - lstm_1_accuracy: 0.9123 - lstm_2_accuracy: 0.9620
# Epoch 00022: val_lstm_2_accuracy did not improve from 0.88480
# 133/133 [==============================] - 5s 36ms/step - loss: 0.3457 - lstm_1_loss: 0.2325 - lstm_2_loss: 0.1133 - lstm_1_accuracy: 0.9123 - lstm_2_accuracy: 0.9620 - val_loss: 0.6306 - val_lstm_1_loss: 0.3132 - val_lstm_2_loss: 0.3174 - val_lstm_1_accuracy: 0.8640 - val_lstm_2_accuracy: 0.8810
# Epoch 23/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3325 - lstm_1_loss: 0.2257 - lstm_2_loss: 0.1068 - lstm_1_accuracy: 0.9166 - lstm_2_accuracy: 0.9664
# Epoch 00023: val_lstm_2_accuracy improved from 0.88480 to 0.88574, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 39ms/step - loss: 0.3325 - lstm_1_loss: 0.2257 - lstm_2_loss: 0.1068 - lstm_1_accuracy: 0.9166 - lstm_2_accuracy: 0.9664 - val_loss: 0.6178 - val_lstm_1_loss: 0.3079 - val_lstm_2_loss: 0.3099 - val_lstm_1_accuracy: 0.8697 - val_lstm_2_accuracy: 0.8857
# Epoch 24/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3247 - lstm_1_loss: 0.2196 - lstm_2_loss: 0.1051 - lstm_1_accuracy: 0.9166 - lstm_2_accuracy: 0.9641
# Epoch 00024: val_lstm_2_accuracy did not improve from 0.88574
# 133/133 [==============================] - 5s 36ms/step - loss: 0.3247 - lstm_1_loss: 0.2196 - lstm_2_loss: 0.1051 - lstm_1_accuracy: 0.9166 - lstm_2_accuracy: 0.9641 - val_loss: 0.6141 - val_lstm_1_loss: 0.3064 - val_lstm_2_loss: 0.3077 - val_lstm_1_accuracy: 0.8716 - val_lstm_2_accuracy: 0.8857
# Epoch 25/100
# 133/133 [==============================] - ETA: 0s - loss: 0.3110 - lstm_1_loss: 0.2170 - lstm_2_loss: 0.0940 - lstm_1_accuracy: 0.9147 - lstm_2_accuracy: 0.9702
# Epoch 00025: val_lstm_2_accuracy improved from 0.88574 to 0.88857, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 39ms/step - loss: 0.3110 - lstm_1_loss: 0.2170 - lstm_2_loss: 0.0940 - lstm_1_accuracy: 0.9147 - lstm_2_accuracy: 0.9702 - val_loss: 0.6281 - val_lstm_1_loss: 0.3009 - val_lstm_2_loss: 0.3272 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8886
# Epoch 26/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2921 - lstm_1_loss: 0.2074 - lstm_2_loss: 0.0847 - lstm_1_accuracy: 0.9241 - lstm_2_accuracy: 0.9738
# Epoch 00026: val_lstm_2_accuracy did not improve from 0.88857
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2921 - lstm_1_loss: 0.2074 - lstm_2_loss: 0.0847 - lstm_1_accuracy: 0.9241 - lstm_2_accuracy: 0.9738 - val_loss: 0.6327 - val_lstm_1_loss: 0.3024 - val_lstm_2_loss: 0.3303 - val_lstm_1_accuracy: 0.8772 - val_lstm_2_accuracy: 0.8791
# Epoch 27/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2871 - lstm_1_loss: 0.2046 - lstm_2_loss: 0.0824 - lstm_1_accuracy: 0.9241 - lstm_2_accuracy: 0.9733
# Epoch 00027: val_lstm_2_accuracy improved from 0.88857 to 0.89424, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 39ms/step - loss: 0.2871 - lstm_1_loss: 0.2046 - lstm_2_loss: 0.0824 - lstm_1_accuracy: 0.9241 - lstm_2_accuracy: 0.9733 - val_loss: 0.6253 - val_lstm_1_loss: 0.2988 - val_lstm_2_loss: 0.3265 - val_lstm_1_accuracy: 0.8706 - val_lstm_2_accuracy: 0.8942
# Epoch 28/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2719 - lstm_1_loss: 0.1970 - lstm_2_loss: 0.0749 - lstm_1_accuracy: 0.9289 - lstm_2_accuracy: 0.9757
# Epoch 00028: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2719 - lstm_1_loss: 0.1970 - lstm_2_loss: 0.0749 - lstm_1_accuracy: 0.9289 - lstm_2_accuracy: 0.9757 - val_loss: 0.6305 - val_lstm_1_loss: 0.3007 - val_lstm_2_loss: 0.3298 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8886
# Epoch 29/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2607 - lstm_1_loss: 0.1916 - lstm_2_loss: 0.0691 - lstm_1_accuracy: 0.9286 - lstm_2_accuracy: 0.9780
# Epoch 00029: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2607 - lstm_1_loss: 0.1916 - lstm_2_loss: 0.0691 - lstm_1_accuracy: 0.9286 - lstm_2_accuracy: 0.9780 - val_loss: 0.6563 - val_lstm_1_loss: 0.3000 - val_lstm_2_loss: 0.3563 - val_lstm_1_accuracy: 0.8754 - val_lstm_2_accuracy: 0.8914
# Epoch 30/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2485 - lstm_1_loss: 0.1874 - lstm_2_loss: 0.0611 - lstm_1_accuracy: 0.9355 - lstm_2_accuracy: 0.9839
# Epoch 00030: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2485 - lstm_1_loss: 0.1874 - lstm_2_loss: 0.0611 - lstm_1_accuracy: 0.9355 - lstm_2_accuracy: 0.9839 - val_loss: 0.6610 - val_lstm_1_loss: 0.2974 - val_lstm_2_loss: 0.3636 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8810
# Epoch 31/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2382 - lstm_1_loss: 0.1822 - lstm_2_loss: 0.0560 - lstm_1_accuracy: 0.9360 - lstm_2_accuracy: 0.9851
# Epoch 00031: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2382 - lstm_1_loss: 0.1822 - lstm_2_loss: 0.0560 - lstm_1_accuracy: 0.9360 - lstm_2_accuracy: 0.9851 - val_loss: 0.6595 - val_lstm_1_loss: 0.2964 - val_lstm_2_loss: 0.3631 - val_lstm_1_accuracy: 0.8763 - val_lstm_2_accuracy: 0.8857
# Epoch 32/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2304 - lstm_1_loss: 0.1770 - lstm_2_loss: 0.0534 - lstm_1_accuracy: 0.9388 - lstm_2_accuracy: 0.9863
# Epoch 00032: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2304 - lstm_1_loss: 0.1770 - lstm_2_loss: 0.0534 - lstm_1_accuracy: 0.9388 - lstm_2_accuracy: 0.9863 - val_loss: 0.6764 - val_lstm_1_loss: 0.2930 - val_lstm_2_loss: 0.3834 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8905
# Epoch 33/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2247 - lstm_1_loss: 0.1735 - lstm_2_loss: 0.0512 - lstm_1_accuracy: 0.9397 - lstm_2_accuracy: 0.9868
# Epoch 00033: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2247 - lstm_1_loss: 0.1735 - lstm_2_loss: 0.0512 - lstm_1_accuracy: 0.9397 - lstm_2_accuracy: 0.9868 - val_loss: 0.6949 - val_lstm_1_loss: 0.2995 - val_lstm_2_loss: 0.3954 - val_lstm_1_accuracy: 0.8820 - val_lstm_2_accuracy: 0.8782
# Epoch 34/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2140 - lstm_1_loss: 0.1673 - lstm_2_loss: 0.0467 - lstm_1_accuracy: 0.9433 - lstm_2_accuracy: 0.9863
# Epoch 00034: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2140 - lstm_1_loss: 0.1673 - lstm_2_loss: 0.0467 - lstm_1_accuracy: 0.9433 - lstm_2_accuracy: 0.9863 - val_loss: 0.6730 - val_lstm_1_loss: 0.2940 - val_lstm_2_loss: 0.3790 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8886
# Epoch 35/100
# 133/133 [==============================] - ETA: 0s - loss: 0.2023 - lstm_1_loss: 0.1612 - lstm_2_loss: 0.0411 - lstm_1_accuracy: 0.9442 - lstm_2_accuracy: 0.9905
# Epoch 00035: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.2023 - lstm_1_loss: 0.1612 - lstm_2_loss: 0.0411 - lstm_1_accuracy: 0.9442 - lstm_2_accuracy: 0.9905 - val_loss: 0.6880 - val_lstm_1_loss: 0.2962 - val_lstm_2_loss: 0.3918 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8914
# Epoch 36/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1988 - lstm_1_loss: 0.1599 - lstm_2_loss: 0.0389 - lstm_1_accuracy: 0.9452 - lstm_2_accuracy: 0.9908
# Epoch 00036: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1988 - lstm_1_loss: 0.1599 - lstm_2_loss: 0.0389 - lstm_1_accuracy: 0.9452 - lstm_2_accuracy: 0.9908 - val_loss: 0.6969 - val_lstm_1_loss: 0.2970 - val_lstm_2_loss: 0.3999 - val_lstm_1_accuracy: 0.8820 - val_lstm_2_accuracy: 0.8924
# Epoch 37/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1914 - lstm_1_loss: 0.1558 - lstm_2_loss: 0.0356 - lstm_1_accuracy: 0.9471 - lstm_2_accuracy: 0.9905
# Epoch 00037: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1914 - lstm_1_loss: 0.1558 - lstm_2_loss: 0.0356 - lstm_1_accuracy: 0.9471 - lstm_2_accuracy: 0.9905 - val_loss: 0.7206 - val_lstm_1_loss: 0.2945 - val_lstm_2_loss: 0.4261 - val_lstm_1_accuracy: 0.8839 - val_lstm_2_accuracy: 0.8886
# Epoch 38/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1939 - lstm_1_loss: 0.1508 - lstm_2_loss: 0.0431 - lstm_1_accuracy: 0.9520 - lstm_2_accuracy: 0.9875
# Epoch 00038: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1939 - lstm_1_loss: 0.1508 - lstm_2_loss: 0.0431 - lstm_1_accuracy: 0.9520 - lstm_2_accuracy: 0.9875 - val_loss: 0.7145 - val_lstm_1_loss: 0.2991 - val_lstm_2_loss: 0.4155 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8857
# Epoch 39/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1875 - lstm_1_loss: 0.1479 - lstm_2_loss: 0.0396 - lstm_1_accuracy: 0.9492 - lstm_2_accuracy: 0.9898
# Epoch 00039: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1875 - lstm_1_loss: 0.1479 - lstm_2_loss: 0.0396 - lstm_1_accuracy: 0.9492 - lstm_2_accuracy: 0.9898 - val_loss: 0.7359 - val_lstm_1_loss: 0.3103 - val_lstm_2_loss: 0.4256 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8905
# Epoch 40/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1737 - lstm_1_loss: 0.1448 - lstm_2_loss: 0.0289 - lstm_1_accuracy: 0.9534 - lstm_2_accuracy: 0.9943
# Epoch 00040: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1737 - lstm_1_loss: 0.1448 - lstm_2_loss: 0.0289 - lstm_1_accuracy: 0.9534 - lstm_2_accuracy: 0.9943 - val_loss: 0.7266 - val_lstm_1_loss: 0.2989 - val_lstm_2_loss: 0.4277 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8924
# Epoch 41/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1693 - lstm_1_loss: 0.1413 - lstm_2_loss: 0.0280 - lstm_1_accuracy: 0.9553 - lstm_2_accuracy: 0.9939
# Epoch 00041: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1693 - lstm_1_loss: 0.1413 - lstm_2_loss: 0.0280 - lstm_1_accuracy: 0.9553 - lstm_2_accuracy: 0.9939 - val_loss: 0.7541 - val_lstm_1_loss: 0.2993 - val_lstm_2_loss: 0.4547 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8839
# Epoch 42/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1607 - lstm_1_loss: 0.1351 - lstm_2_loss: 0.0256 - lstm_1_accuracy: 0.9556 - lstm_2_accuracy: 0.9948
# Epoch 00042: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1607 - lstm_1_loss: 0.1351 - lstm_2_loss: 0.0256 - lstm_1_accuracy: 0.9556 - lstm_2_accuracy: 0.9948 - val_loss: 0.7418 - val_lstm_1_loss: 0.2997 - val_lstm_2_loss: 0.4422 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8886
# Epoch 43/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1542 - lstm_1_loss: 0.1312 - lstm_2_loss: 0.0230 - lstm_1_accuracy: 0.9589 - lstm_2_accuracy: 0.9948
# Epoch 00043: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1542 - lstm_1_loss: 0.1312 - lstm_2_loss: 0.0230 - lstm_1_accuracy: 0.9589 - lstm_2_accuracy: 0.9948 - val_loss: 0.7622 - val_lstm_1_loss: 0.2994 - val_lstm_2_loss: 0.4627 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8895
# Epoch 44/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1502 - lstm_1_loss: 0.1283 - lstm_2_loss: 0.0219 - lstm_1_accuracy: 0.9605 - lstm_2_accuracy: 0.9946
# Epoch 00044: val_lstm_2_accuracy did not improve from 0.89424
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1502 - lstm_1_loss: 0.1283 - lstm_2_loss: 0.0219 - lstm_1_accuracy: 0.9605 - lstm_2_accuracy: 0.9946 - val_loss: 0.7862 - val_lstm_1_loss: 0.2995 - val_lstm_2_loss: 0.4867 - val_lstm_1_accuracy: 0.8848 - val_lstm_2_accuracy: 0.8848
# Epoch 45/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1457 - lstm_1_loss: 0.1248 - lstm_2_loss: 0.0209 - lstm_1_accuracy: 0.9631 - lstm_2_accuracy: 0.9962
# Epoch 00045: val_lstm_2_accuracy improved from 0.89424 to 0.89707, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 39ms/step - loss: 0.1457 - lstm_1_loss: 0.1248 - lstm_2_loss: 0.0209 - lstm_1_accuracy: 0.9631 - lstm_2_accuracy: 0.9962 - val_loss: 0.7646 - val_lstm_1_loss: 0.3096 - val_lstm_2_loss: 0.4549 - val_lstm_1_accuracy: 0.8754 - val_lstm_2_accuracy: 0.8971
# Epoch 46/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1472 - lstm_1_loss: 0.1218 - lstm_2_loss: 0.0254 - lstm_1_accuracy: 0.9648 - lstm_2_accuracy: 0.9934
# Epoch 00046: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1472 - lstm_1_loss: 0.1218 - lstm_2_loss: 0.0254 - lstm_1_accuracy: 0.9648 - lstm_2_accuracy: 0.9934 - val_loss: 0.7425 - val_lstm_1_loss: 0.3062 - val_lstm_2_loss: 0.4362 - val_lstm_1_accuracy: 0.8829 - val_lstm_2_accuracy: 0.8886
# Epoch 47/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1405 - lstm_1_loss: 0.1184 - lstm_2_loss: 0.0221 - lstm_1_accuracy: 0.9636 - lstm_2_accuracy: 0.9962
# Epoch 00047: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1405 - lstm_1_loss: 0.1184 - lstm_2_loss: 0.0221 - lstm_1_accuracy: 0.9636 - lstm_2_accuracy: 0.9962 - val_loss: 0.7705 - val_lstm_1_loss: 0.3012 - val_lstm_2_loss: 0.4694 - val_lstm_1_accuracy: 0.8839 - val_lstm_2_accuracy: 0.8895
# Epoch 48/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1329 - lstm_1_loss: 0.1151 - lstm_2_loss: 0.0177 - lstm_1_accuracy: 0.9669 - lstm_2_accuracy: 0.9962
# Epoch 00048: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1329 - lstm_1_loss: 0.1151 - lstm_2_loss: 0.0177 - lstm_1_accuracy: 0.9669 - lstm_2_accuracy: 0.9962 - val_loss: 0.8288 - val_lstm_1_loss: 0.3070 - val_lstm_2_loss: 0.5219 - val_lstm_1_accuracy: 0.8886 - val_lstm_2_accuracy: 0.8867
# Epoch 49/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1357 - lstm_1_loss: 0.1126 - lstm_2_loss: 0.0231 - lstm_1_accuracy: 0.9646 - lstm_2_accuracy: 0.9941
# Epoch 00049: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1357 - lstm_1_loss: 0.1126 - lstm_2_loss: 0.0231 - lstm_1_accuracy: 0.9646 - lstm_2_accuracy: 0.9941 - val_loss: 0.7498 - val_lstm_1_loss: 0.3041 - val_lstm_2_loss: 0.4456 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8782
# Epoch 50/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1277 - lstm_1_loss: 0.1091 - lstm_2_loss: 0.0186 - lstm_1_accuracy: 0.9662 - lstm_2_accuracy: 0.9967
# Epoch 00050: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1277 - lstm_1_loss: 0.1091 - lstm_2_loss: 0.0186 - lstm_1_accuracy: 0.9662 - lstm_2_accuracy: 0.9967 - val_loss: 0.7781 - val_lstm_1_loss: 0.3023 - val_lstm_2_loss: 0.4759 - val_lstm_1_accuracy: 0.8857 - val_lstm_2_accuracy: 0.8961
# Epoch 51/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1191 - lstm_1_loss: 0.1045 - lstm_2_loss: 0.0146 - lstm_1_accuracy: 0.9705 - lstm_2_accuracy: 0.9976
# Epoch 00051: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1191 - lstm_1_loss: 0.1045 - lstm_2_loss: 0.0146 - lstm_1_accuracy: 0.9705 - lstm_2_accuracy: 0.9976 - val_loss: 0.7696 - val_lstm_1_loss: 0.3067 - val_lstm_2_loss: 0.4630 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8914
# Epoch 52/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1176 - lstm_1_loss: 0.1022 - lstm_2_loss: 0.0154 - lstm_1_accuracy: 0.9712 - lstm_2_accuracy: 0.9976
# Epoch 00052: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1176 - lstm_1_loss: 0.1022 - lstm_2_loss: 0.0154 - lstm_1_accuracy: 0.9712 - lstm_2_accuracy: 0.9976 - val_loss: 0.8109 - val_lstm_1_loss: 0.3069 - val_lstm_2_loss: 0.5040 - val_lstm_1_accuracy: 0.8829 - val_lstm_2_accuracy: 0.8876
# Epoch 53/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1179 - lstm_1_loss: 0.0994 - lstm_2_loss: 0.0185 - lstm_1_accuracy: 0.9721 - lstm_2_accuracy: 0.9955
# Epoch 00053: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1179 - lstm_1_loss: 0.0994 - lstm_2_loss: 0.0185 - lstm_1_accuracy: 0.9721 - lstm_2_accuracy: 0.9955 - val_loss: 0.7810 - val_lstm_1_loss: 0.3072 - val_lstm_2_loss: 0.4738 - val_lstm_1_accuracy: 0.8820 - val_lstm_2_accuracy: 0.8914
# Epoch 54/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1120 - lstm_1_loss: 0.0959 - lstm_2_loss: 0.0161 - lstm_1_accuracy: 0.9726 - lstm_2_accuracy: 0.9976
# Epoch 00054: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1120 - lstm_1_loss: 0.0959 - lstm_2_loss: 0.0161 - lstm_1_accuracy: 0.9726 - lstm_2_accuracy: 0.9976 - val_loss: 0.8060 - val_lstm_1_loss: 0.3094 - val_lstm_2_loss: 0.4966 - val_lstm_1_accuracy: 0.8829 - val_lstm_2_accuracy: 0.8914
# Epoch 55/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1049 - lstm_1_loss: 0.0922 - lstm_2_loss: 0.0127 - lstm_1_accuracy: 0.9754 - lstm_2_accuracy: 0.9979
# Epoch 00055: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1049 - lstm_1_loss: 0.0922 - lstm_2_loss: 0.0127 - lstm_1_accuracy: 0.9754 - lstm_2_accuracy: 0.9979 - val_loss: 0.8070 - val_lstm_1_loss: 0.3154 - val_lstm_2_loss: 0.4916 - val_lstm_1_accuracy: 0.8848 - val_lstm_2_accuracy: 0.8895
# Epoch 56/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1019 - lstm_1_loss: 0.0902 - lstm_2_loss: 0.0117 - lstm_1_accuracy: 0.9764 - lstm_2_accuracy: 0.9983
# Epoch 00056: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1019 - lstm_1_loss: 0.0902 - lstm_2_loss: 0.0117 - lstm_1_accuracy: 0.9764 - lstm_2_accuracy: 0.9983 - val_loss: 0.8038 - val_lstm_1_loss: 0.3173 - val_lstm_2_loss: 0.4865 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8924
# Epoch 57/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1011 - lstm_1_loss: 0.0885 - lstm_2_loss: 0.0126 - lstm_1_accuracy: 0.9771 - lstm_2_accuracy: 0.9976
# Epoch 00057: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1011 - lstm_1_loss: 0.0885 - lstm_2_loss: 0.0126 - lstm_1_accuracy: 0.9771 - lstm_2_accuracy: 0.9976 - val_loss: 0.7924 - val_lstm_1_loss: 0.3214 - val_lstm_2_loss: 0.4710 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8961
# Epoch 58/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1118 - lstm_1_loss: 0.0854 - lstm_2_loss: 0.0264 - lstm_1_accuracy: 0.9768 - lstm_2_accuracy: 0.9924
# Epoch 00058: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1118 - lstm_1_loss: 0.0854 - lstm_2_loss: 0.0264 - lstm_1_accuracy: 0.9768 - lstm_2_accuracy: 0.9924 - val_loss: 0.7754 - val_lstm_1_loss: 0.3239 - val_lstm_2_loss: 0.4516 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8857
# Epoch 59/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0967 - lstm_1_loss: 0.0832 - lstm_2_loss: 0.0135 - lstm_1_accuracy: 0.9778 - lstm_2_accuracy: 0.9976
# Epoch 00059: val_lstm_2_accuracy did not improve from 0.89707
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0967 - lstm_1_loss: 0.0832 - lstm_2_loss: 0.0135 - lstm_1_accuracy: 0.9778 - lstm_2_accuracy: 0.9976 - val_loss: 0.8318 - val_lstm_1_loss: 0.3277 - val_lstm_2_loss: 0.5041 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8924
# Epoch 60/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0915 - lstm_1_loss: 0.0803 - lstm_2_loss: 0.0112 - lstm_1_accuracy: 0.9785 - lstm_2_accuracy: 0.9983
# Epoch 00060: val_lstm_2_accuracy improved from 0.89707 to 0.89802, saving model to ./weight_cp\weight_lstm.hdf5
# 133/133 [==============================] - 5s 39ms/step - loss: 0.0915 - lstm_1_loss: 0.0803 - lstm_2_loss: 0.0112 - lstm_1_accuracy: 0.9785 - lstm_2_accuracy: 0.9983 - val_loss: 0.8235 - val_lstm_1_loss: 0.3348 - val_lstm_2_loss: 0.4887 - val_lstm_1_accuracy: 0.8763 - val_lstm_2_accuracy: 0.8980
# Epoch 61/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1022 - lstm_1_loss: 0.0831 - lstm_2_loss: 0.0191 - lstm_1_accuracy: 0.9747 - lstm_2_accuracy: 0.9948
# Epoch 00061: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1022 - lstm_1_loss: 0.0831 - lstm_2_loss: 0.0191 - lstm_1_accuracy: 0.9747 - lstm_2_accuracy: 0.9948 - val_loss: 0.8136 - val_lstm_1_loss: 0.3509 - val_lstm_2_loss: 0.4627 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8867
# Epoch 62/100
# 133/133 [==============================] - ETA: 0s - loss: 0.1121 - lstm_1_loss: 0.0845 - lstm_2_loss: 0.0276 - lstm_1_accuracy: 0.9759 - lstm_2_accuracy: 0.9922
# Epoch 00062: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.1121 - lstm_1_loss: 0.0845 - lstm_2_loss: 0.0276 - lstm_1_accuracy: 0.9759 - lstm_2_accuracy: 0.9922 - val_loss: 0.7399 - val_lstm_1_loss: 0.3291 - val_lstm_2_loss: 0.4107 - val_lstm_1_accuracy: 0.8725 - val_lstm_2_accuracy: 0.8971
# Epoch 63/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0951 - lstm_1_loss: 0.0772 - lstm_2_loss: 0.0180 - lstm_1_accuracy: 0.9811 - lstm_2_accuracy: 0.9950
# Epoch 00063: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0951 - lstm_1_loss: 0.0772 - lstm_2_loss: 0.0180 - lstm_1_accuracy: 0.9811 - lstm_2_accuracy: 0.9950 - val_loss: 0.8327 - val_lstm_1_loss: 0.3365 - val_lstm_2_loss: 0.4962 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8867
# Epoch 64/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0849 - lstm_1_loss: 0.0738 - lstm_2_loss: 0.0111 - lstm_1_accuracy: 0.9799 - lstm_2_accuracy: 0.9979
# Epoch 00064: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0849 - lstm_1_loss: 0.0738 - lstm_2_loss: 0.0111 - lstm_1_accuracy: 0.9799 - lstm_2_accuracy: 0.9979 - val_loss: 0.8465 - val_lstm_1_loss: 0.3360 - val_lstm_2_loss: 0.5105 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8924
# Epoch 65/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0800 - lstm_1_loss: 0.0709 - lstm_2_loss: 0.0091 - lstm_1_accuracy: 0.9830 - lstm_2_accuracy: 0.9986
# Epoch 00065: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0800 - lstm_1_loss: 0.0709 - lstm_2_loss: 0.0091 - lstm_1_accuracy: 0.9830 - lstm_2_accuracy: 0.9986 - val_loss: 0.8516 - val_lstm_1_loss: 0.3346 - val_lstm_2_loss: 0.5171 - val_lstm_1_accuracy: 0.8848 - val_lstm_2_accuracy: 0.8905
# Epoch 66/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0786 - lstm_1_loss: 0.0700 - lstm_2_loss: 0.0087 - lstm_1_accuracy: 0.9825 - lstm_2_accuracy: 0.9986
# Epoch 00066: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0786 - lstm_1_loss: 0.0700 - lstm_2_loss: 0.0087 - lstm_1_accuracy: 0.9825 - lstm_2_accuracy: 0.9986 - val_loss: 0.8485 - val_lstm_1_loss: 0.3401 - val_lstm_2_loss: 0.5084 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8876
# Epoch 67/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0790 - lstm_1_loss: 0.0686 - lstm_2_loss: 0.0105 - lstm_1_accuracy: 0.9832 - lstm_2_accuracy: 0.9981
# Epoch 00067: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0790 - lstm_1_loss: 0.0686 - lstm_2_loss: 0.0105 - lstm_1_accuracy: 0.9832 - lstm_2_accuracy: 0.9981 - val_loss: 0.8552 - val_lstm_1_loss: 0.3416 - val_lstm_2_loss: 0.5136 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8886
# Epoch 68/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0748 - lstm_1_loss: 0.0670 - lstm_2_loss: 0.0079 - lstm_1_accuracy: 0.9839 - lstm_2_accuracy: 0.9986
# Epoch 00068: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0748 - lstm_1_loss: 0.0670 - lstm_2_loss: 0.0079 - lstm_1_accuracy: 0.9839 - lstm_2_accuracy: 0.9986 - val_loss: 0.8564 - val_lstm_1_loss: 0.3493 - val_lstm_2_loss: 0.5071 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8933
# Epoch 69/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0884 - lstm_1_loss: 0.0649 - lstm_2_loss: 0.0234 - lstm_1_accuracy: 0.9839 - lstm_2_accuracy: 0.9915
# Epoch 00069: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0884 - lstm_1_loss: 0.0649 - lstm_2_loss: 0.0234 - lstm_1_accuracy: 0.9839 - lstm_2_accuracy: 0.9915 - val_loss: 0.8520 - val_lstm_1_loss: 0.3553 - val_lstm_2_loss: 0.4968 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8876
# Epoch 70/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0748 - lstm_1_loss: 0.0642 - lstm_2_loss: 0.0106 - lstm_1_accuracy: 0.9837 - lstm_2_accuracy: 0.9981
# Epoch 00070: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0748 - lstm_1_loss: 0.0642 - lstm_2_loss: 0.0106 - lstm_1_accuracy: 0.9837 - lstm_2_accuracy: 0.9981 - val_loss: 0.8685 - val_lstm_1_loss: 0.3570 - val_lstm_2_loss: 0.5115 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8801
# Epoch 71/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0704 - lstm_1_loss: 0.0618 - lstm_2_loss: 0.0087 - lstm_1_accuracy: 0.9851 - lstm_2_accuracy: 0.9986
# Epoch 00071: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0704 - lstm_1_loss: 0.0618 - lstm_2_loss: 0.0087 - lstm_1_accuracy: 0.9851 - lstm_2_accuracy: 0.9986 - val_loss: 0.8808 - val_lstm_1_loss: 0.3599 - val_lstm_2_loss: 0.5209 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8942
# Epoch 72/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0672 - lstm_1_loss: 0.0599 - lstm_2_loss: 0.0073 - lstm_1_accuracy: 0.9858 - lstm_2_accuracy: 0.9991
# Epoch 00072: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0672 - lstm_1_loss: 0.0599 - lstm_2_loss: 0.0073 - lstm_1_accuracy: 0.9858 - lstm_2_accuracy: 0.9991 - val_loss: 0.8825 - val_lstm_1_loss: 0.3631 - val_lstm_2_loss: 0.5194 - val_lstm_1_accuracy: 0.8772 - val_lstm_2_accuracy: 0.8924
# Epoch 73/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0656 - lstm_1_loss: 0.0585 - lstm_2_loss: 0.0071 - lstm_1_accuracy: 0.9863 - lstm_2_accuracy: 0.9988
# Epoch 00073: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0656 - lstm_1_loss: 0.0585 - lstm_2_loss: 0.0071 - lstm_1_accuracy: 0.9863 - lstm_2_accuracy: 0.9988 - val_loss: 0.8933 - val_lstm_1_loss: 0.3655 - val_lstm_2_loss: 0.5278 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8942
# Epoch 74/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0667 - lstm_1_loss: 0.0574 - lstm_2_loss: 0.0093 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9974
# Epoch 00074: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0667 - lstm_1_loss: 0.0574 - lstm_2_loss: 0.0093 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9974 - val_loss: 0.9049 - val_lstm_1_loss: 0.3671 - val_lstm_2_loss: 0.5379 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8886
# Epoch 75/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0676 - lstm_1_loss: 0.0560 - lstm_2_loss: 0.0116 - lstm_1_accuracy: 0.9865 - lstm_2_accuracy: 0.9967
# Epoch 00075: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0676 - lstm_1_loss: 0.0560 - lstm_2_loss: 0.0116 - lstm_1_accuracy: 0.9865 - lstm_2_accuracy: 0.9967 - val_loss: 0.8653 - val_lstm_1_loss: 0.3742 - val_lstm_2_loss: 0.4911 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8905
# Epoch 76/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0640 - lstm_1_loss: 0.0545 - lstm_2_loss: 0.0095 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9979
# Epoch 00076: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0640 - lstm_1_loss: 0.0545 - lstm_2_loss: 0.0095 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9979 - val_loss: 0.9362 - val_lstm_1_loss: 0.3860 - val_lstm_2_loss: 0.5502 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8895
# Epoch 77/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0634 - lstm_1_loss: 0.0550 - lstm_2_loss: 0.0084 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9981
# Epoch 00077: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0634 - lstm_1_loss: 0.0550 - lstm_2_loss: 0.0084 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9981 - val_loss: 0.9174 - val_lstm_1_loss: 0.3770 - val_lstm_2_loss: 0.5404 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8924
# Epoch 78/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0577 - lstm_1_loss: 0.0516 - lstm_2_loss: 0.0061 - lstm_1_accuracy: 0.9882 - lstm_2_accuracy: 0.9988
# Epoch 00078: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0577 - lstm_1_loss: 0.0516 - lstm_2_loss: 0.0061 - lstm_1_accuracy: 0.9882 - lstm_2_accuracy: 0.9988 - val_loss: 0.9530 - val_lstm_1_loss: 0.3846 - val_lstm_2_loss: 0.5684 - val_lstm_1_accuracy: 0.8744 - val_lstm_2_accuracy: 0.8924
# Epoch 79/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0606 - lstm_1_loss: 0.0515 - lstm_2_loss: 0.0091 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9974
# Epoch 00079: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0606 - lstm_1_loss: 0.0515 - lstm_2_loss: 0.0091 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9974 - val_loss: 0.9195 - val_lstm_1_loss: 0.3786 - val_lstm_2_loss: 0.5409 - val_lstm_1_accuracy: 0.8801 - val_lstm_2_accuracy: 0.8895
# Epoch 80/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0583 - lstm_1_loss: 0.0500 - lstm_2_loss: 0.0083 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9988
# Epoch 00080: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0583 - lstm_1_loss: 0.0500 - lstm_2_loss: 0.0083 - lstm_1_accuracy: 0.9877 - lstm_2_accuracy: 0.9988 - val_loss: 0.9484 - val_lstm_1_loss: 0.3874 - val_lstm_2_loss: 0.5611 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8924
# Epoch 81/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0554 - lstm_1_loss: 0.0482 - lstm_2_loss: 0.0072 - lstm_1_accuracy: 0.9903 - lstm_2_accuracy: 0.9983
# Epoch 00081: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0554 - lstm_1_loss: 0.0482 - lstm_2_loss: 0.0072 - lstm_1_accuracy: 0.9903 - lstm_2_accuracy: 0.9983 - val_loss: 1.0118 - val_lstm_1_loss: 0.3965 - val_lstm_2_loss: 0.6153 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8782
# Epoch 82/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0602 - lstm_1_loss: 0.0501 - lstm_2_loss: 0.0101 - lstm_1_accuracy: 0.9882 - lstm_2_accuracy: 0.9979
# Epoch 00082: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0602 - lstm_1_loss: 0.0501 - lstm_2_loss: 0.0101 - lstm_1_accuracy: 0.9882 - lstm_2_accuracy: 0.9979 - val_loss: 1.0275 - val_lstm_1_loss: 0.4261 - val_lstm_2_loss: 0.6014 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8895
# Epoch 83/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0562 - lstm_1_loss: 0.0485 - lstm_2_loss: 0.0078 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9986
# Epoch 00083: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0562 - lstm_1_loss: 0.0485 - lstm_2_loss: 0.0078 - lstm_1_accuracy: 0.9884 - lstm_2_accuracy: 0.9986 - val_loss: 0.9324 - val_lstm_1_loss: 0.3978 - val_lstm_2_loss: 0.5346 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8952
# Epoch 84/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0504 - lstm_1_loss: 0.0454 - lstm_2_loss: 0.0050 - lstm_1_accuracy: 0.9910 - lstm_2_accuracy: 0.9993
# Epoch 00084: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0504 - lstm_1_loss: 0.0454 - lstm_2_loss: 0.0050 - lstm_1_accuracy: 0.9910 - lstm_2_accuracy: 0.9993 - val_loss: 0.9383 - val_lstm_1_loss: 0.3919 - val_lstm_2_loss: 0.5465 - val_lstm_1_accuracy: 0.8829 - val_lstm_2_accuracy: 0.8933
# Epoch 85/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0505 - lstm_1_loss: 0.0449 - lstm_2_loss: 0.0056 - lstm_1_accuracy: 0.9898 - lstm_2_accuracy: 0.9991
# Epoch 00085: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0505 - lstm_1_loss: 0.0449 - lstm_2_loss: 0.0056 - lstm_1_accuracy: 0.9898 - lstm_2_accuracy: 0.9991 - val_loss: 0.9336 - val_lstm_1_loss: 0.3948 - val_lstm_2_loss: 0.5388 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8914
# Epoch 86/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0543 - lstm_1_loss: 0.0439 - lstm_2_loss: 0.0104 - lstm_1_accuracy: 0.9905 - lstm_2_accuracy: 0.9976
# Epoch 00086: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0543 - lstm_1_loss: 0.0439 - lstm_2_loss: 0.0104 - lstm_1_accuracy: 0.9905 - lstm_2_accuracy: 0.9976 - val_loss: 0.9302 - val_lstm_1_loss: 0.3946 - val_lstm_2_loss: 0.5355 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8867
# Epoch 87/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0513 - lstm_1_loss: 0.0417 - lstm_2_loss: 0.0096 - lstm_1_accuracy: 0.9917 - lstm_2_accuracy: 0.9976
# Epoch 00087: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0513 - lstm_1_loss: 0.0417 - lstm_2_loss: 0.0096 - lstm_1_accuracy: 0.9917 - lstm_2_accuracy: 0.9976 - val_loss: 0.9191 - val_lstm_1_loss: 0.4031 - val_lstm_2_loss: 0.5160 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8867
# Epoch 88/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0564 - lstm_1_loss: 0.0420 - lstm_2_loss: 0.0145 - lstm_1_accuracy: 0.9913 - lstm_2_accuracy: 0.9957
# Epoch 00088: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0564 - lstm_1_loss: 0.0420 - lstm_2_loss: 0.0145 - lstm_1_accuracy: 0.9913 - lstm_2_accuracy: 0.9957 - val_loss: 0.9342 - val_lstm_1_loss: 0.4067 - val_lstm_2_loss: 0.5275 - val_lstm_1_accuracy: 0.8782 - val_lstm_2_accuracy: 0.8914
# Epoch 89/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0954 - lstm_1_loss: 0.0704 - lstm_2_loss: 0.0250 - lstm_1_accuracy: 0.9804 - lstm_2_accuracy: 0.9929
# Epoch 00089: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0954 - lstm_1_loss: 0.0704 - lstm_2_loss: 0.0250 - lstm_1_accuracy: 0.9804 - lstm_2_accuracy: 0.9929 - val_loss: 0.8951 - val_lstm_1_loss: 0.3896 - val_lstm_2_loss: 0.5055 - val_lstm_1_accuracy: 0.8735 - val_lstm_2_accuracy: 0.8867
# Epoch 90/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0468 - lstm_1_loss: 0.0416 - lstm_2_loss: 0.0052 - lstm_1_accuracy: 0.9915 - lstm_2_accuracy: 0.9993
# Epoch 00090: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0468 - lstm_1_loss: 0.0416 - lstm_2_loss: 0.0052 - lstm_1_accuracy: 0.9915 - lstm_2_accuracy: 0.9993 - val_loss: 0.9371 - val_lstm_1_loss: 0.3938 - val_lstm_2_loss: 0.5433 - val_lstm_1_accuracy: 0.8754 - val_lstm_2_accuracy: 0.8905
# Epoch 91/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0444 - lstm_1_loss: 0.0398 - lstm_2_loss: 0.0045 - lstm_1_accuracy: 0.9915 - lstm_2_accuracy: 0.9993
# Epoch 00091: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0444 - lstm_1_loss: 0.0398 - lstm_2_loss: 0.0045 - lstm_1_accuracy: 0.9915 - lstm_2_accuracy: 0.9993 - val_loss: 0.9705 - val_lstm_1_loss: 0.3986 - val_lstm_2_loss: 0.5719 - val_lstm_1_accuracy: 0.8763 - val_lstm_2_accuracy: 0.8905
# Epoch 92/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0425 - lstm_1_loss: 0.0385 - lstm_2_loss: 0.0040 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995
# Epoch 00092: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0425 - lstm_1_loss: 0.0385 - lstm_2_loss: 0.0040 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995 - val_loss: 0.9710 - val_lstm_1_loss: 0.4027 - val_lstm_2_loss: 0.5683 - val_lstm_1_accuracy: 0.8754 - val_lstm_2_accuracy: 0.8933
# Epoch 93/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0413 - lstm_1_loss: 0.0374 - lstm_2_loss: 0.0039 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995
# Epoch 00093: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0413 - lstm_1_loss: 0.0374 - lstm_2_loss: 0.0039 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995 - val_loss: 0.9947 - val_lstm_1_loss: 0.4011 - val_lstm_2_loss: 0.5936 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8905
# Epoch 94/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0404 - lstm_1_loss: 0.0368 - lstm_2_loss: 0.0036 - lstm_1_accuracy: 0.9913 - lstm_2_accuracy: 0.9995
# Epoch 00094: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0404 - lstm_1_loss: 0.0368 - lstm_2_loss: 0.0036 - lstm_1_accuracy: 0.9913 - lstm_2_accuracy: 0.9995 - val_loss: 0.9995 - val_lstm_1_loss: 0.4073 - val_lstm_2_loss: 0.5922 - val_lstm_1_accuracy: 0.8810 - val_lstm_2_accuracy: 0.8961
# Epoch 95/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0393 - lstm_1_loss: 0.0358 - lstm_2_loss: 0.0035 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995
# Epoch 00095: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0393 - lstm_1_loss: 0.0358 - lstm_2_loss: 0.0035 - lstm_1_accuracy: 0.9922 - lstm_2_accuracy: 0.9995 - val_loss: 1.0081 - val_lstm_1_loss: 0.4135 - val_lstm_2_loss: 0.5947 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8942
# Epoch 96/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0409 - lstm_1_loss: 0.0354 - lstm_2_loss: 0.0055 - lstm_1_accuracy: 0.9927 - lstm_2_accuracy: 0.9988
# Epoch 00096: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0409 - lstm_1_loss: 0.0354 - lstm_2_loss: 0.0055 - lstm_1_accuracy: 0.9927 - lstm_2_accuracy: 0.9988 - val_loss: 0.9774 - val_lstm_1_loss: 0.4145 - val_lstm_2_loss: 0.5629 - val_lstm_1_accuracy: 0.8820 - val_lstm_2_accuracy: 0.8905
# Epoch 97/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0389 - lstm_1_loss: 0.0348 - lstm_2_loss: 0.0041 - lstm_1_accuracy: 0.9929 - lstm_2_accuracy: 0.9995
# Epoch 00097: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0389 - lstm_1_loss: 0.0348 - lstm_2_loss: 0.0041 - lstm_1_accuracy: 0.9929 - lstm_2_accuracy: 0.9995 - val_loss: 1.0146 - val_lstm_1_loss: 0.4209 - val_lstm_2_loss: 0.5937 - val_lstm_1_accuracy: 0.8772 - val_lstm_2_accuracy: 0.8914
# Epoch 98/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0378 - lstm_1_loss: 0.0343 - lstm_2_loss: 0.0034 - lstm_1_accuracy: 0.9927 - lstm_2_accuracy: 0.9995
# Epoch 00098: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 36ms/step - loss: 0.0378 - lstm_1_loss: 0.0343 - lstm_2_loss: 0.0034 - lstm_1_accuracy: 0.9927 - lstm_2_accuracy: 0.9995 - val_loss: 1.0280 - val_lstm_1_loss: 0.4224 - val_lstm_2_loss: 0.6056 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8876
# Epoch 99/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0368 - lstm_1_loss: 0.0335 - lstm_2_loss: 0.0033 - lstm_1_accuracy: 0.9941 - lstm_2_accuracy: 0.9995
# Epoch 00099: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0368 - lstm_1_loss: 0.0335 - lstm_2_loss: 0.0033 - lstm_1_accuracy: 0.9941 - lstm_2_accuracy: 0.9995 - val_loss: 1.0502 - val_lstm_1_loss: 0.4285 - val_lstm_2_loss: 0.6216 - val_lstm_1_accuracy: 0.8772 - val_lstm_2_accuracy: 0.8895
# Epoch 100/100
# 133/133 [==============================] - ETA: 0s - loss: 0.0357 - lstm_1_loss: 0.0326 - lstm_2_loss: 0.0032 - lstm_1_accuracy: 0.9934 - lstm_2_accuracy: 0.9995
# Epoch 00100: val_lstm_2_accuracy did not improve from 0.89802
# 133/133 [==============================] - 5s 37ms/step - loss: 0.0357 - lstm_1_loss: 0.0326 - lstm_2_loss: 0.0032 - lstm_1_accuracy: 0.9934 - lstm_2_accuracy: 0.9995 - val_loss: 1.0544 - val_lstm_1_loss: 0.4306 - val_lstm_2_loss: 0.6238 - val_lstm_1_accuracy: 0.8791 - val_lstm_2_accuracy: 0.8876

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['val_lstm_1_accuracy'])
plt.plot(history.history['val_lstm_2_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['val_lstm_1_accuracy', 'val_lstm_2_accuracy'], loc='upper left')
plt.show()

# %%
model = load_model('./weight_cp/weight_lstm.hdf5')
predictions1 = model.predict(X_test)[0]
predictions2 = model.predict(X_test)[1]
print(predictions1.shape)
predictions = np.mean((predictions1, predictions2), axis=0)
print(predictions.shape)
predictions = np.where(predictions > 0.5, 1, 0)
y_pred = []
for p in predictions:
    y_pred.append(p[0])
y_pred = np.array(y_pred)
from sklearn.metrics import classification_report, accuracy_score
print("CLASSIFICATION REPORT OF LSTM DS (Averaged)")
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# (1323, 1)
# (1323, 1)
# CLASSIFICATION REPORT OF LSTM DS (Averaged)
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       661
#            1       0.89      0.89      0.89       662
#
#     accuracy                           0.89      1323
#    macro avg       0.89      0.89      0.89      1323
# weighted avg       0.89      0.89      0.89      1323
#
# 0.8934240362811792

# %%
predictions = np.where(predictions2 > 0.5, 1, 0)
y_pred = []
for p in predictions:
    y_pred.append(p[0])
y_pred = np.array(y_pred)
from sklearn.metrics import classification_report, accuracy_score
print("CLASSIFICATION REPORT OF LSTM DS (Last Layer)")
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# CLASSIFICATION REPORT OF LSTM DS (Last Layer)
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       661
#            1       0.88      0.90      0.89       662
#
#     accuracy                           0.89      1323
#    macro avg       0.89      0.89      0.89      1323
# weighted avg       0.89      0.89      0.89      1323
#
# 0.8858654572940288

# %%
predictions = np.where(predictions1 > 0.5, 1, 0)
y_pred = []
for p in predictions:
    y_pred.append(p[0])
y_pred = np.array(y_pred)
from sklearn.metrics import classification_report, accuracy_score
print("CLASSIFICATION REPORT OF LSTM DS (First Layer)")
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# CLASSIFICATION REPORT OF LSTM DS (First Layer)
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       661
#            1       0.90      0.86      0.88       662
#
#     accuracy                           0.88      1323
#    macro avg       0.88      0.88      0.88      1323
# weighted avg       0.88      0.88      0.88      1323
#
# 0.8820861678004536
